# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt
df = pd.read_csv('Student.csv')
sns.set_style("whitegrid")
df.head(10)
# Out:
#    Student_ID       Name  Age  Gender Department  Semester  CGPA  \
# 0        1001  Student_0   24   Other       Math         3   NaN
# 1        1002  Student_1   21  Female         EE         1  3.94
# 2        1003  Student_2   22   Other         EE         5  2.44
# 3        1004  Student_3   24    Male         EE         4  3.47
# 4        1005  Student_4   20    Male         CS         2  3.53
# 5        1006  Student_5   22    Male       Math         1  3.86
# 6        1007  Student_6   22  Female       Math         3  2.06
# 7        1008  Student_7   24    Male    Physics         7  3.74
# 8        1009  Student_8   19  Female    Physics         6  3.05
# 9        1010  Student_9   20    Male    Physics         7  3.27
#
#    Attendance_Rate  Scholarship Admission_Date  Midterm_Marks  Final_Marks  \
# 0             61.0        False     2021-09-11             26           33
# 1             98.0        False     2020-01-26              0           39
# 2             66.0        False     2022-08-14             20           46
# 3             91.0        False     2021-02-24             19           14
# 4             79.0        False     2021-10-24             12           10
# 5             78.0        False     2020-08-08             29           21
# 6             68.0        False     2022-05-02              8           23
# 7             95.0        False     2021-05-10             14            0
# 8             60.0        False     2020-08-24              2           17
# 9             83.0         True     2020-08-24             13           43
#
#          City  Study_Hours_Per_Day    Fees_Paid
# 0      Multan                   10          NaN
# 1      Lahore                    5  Installment
# 2  Faisalabad                    7         Full
# 3  Faisalabad                    8         Full
# 4     Karachi                    3  Installment
# 5      Lahore                    2          NaN
# 6   Islamabad                    2         Full
# 7      Lahore                    5      Pending
# 8  Faisalabad                    1      Pending
# 9     Karachi                    2         Full

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Student_ID           1030 non-null   int64
#  1   Name                 1030 non-null   str
#  2   Age                  1030 non-null   int64
#  3   Gender               1030 non-null   str
#  4   Department           1030 non-null   str
#  5   Semester             1030 non-null   int64
#  6   CGPA                 979 non-null    float64
#  7   Attendance_Rate      999 non-null    float64
#  8   Scholarship          1030 non-null   bool
#  9   Admission_Date       1030 non-null   str
#  10  Midterm_Marks        1030 non-null   int64
#  11  Final_Marks          1030 non-null   int64
#  12  City                 1030 non-null   str
#  13  Study_Hours_Per_Day  1030 non-null   int64
#  14  Fees_Paid            1008 non-null   str
# dtypes: bool(1), float64(2), int64(6), str(6)
# memory usage: 113.8 KB

# %%
df.describe()
# Out:
#         Student_ID          Age     Semester        CGPA  Attendance_Rate  \
# count  1030.000000  1030.000000  1030.000000  979.000000       999.000000
# mean   1486.373786    20.971845     4.448544    3.046558        74.733734
# std     296.048992     1.996154     2.270094    0.574487        14.213981
# min    1001.000000    18.000000     1.000000    2.000000        50.000000
# 25%    1228.250000    19.000000     3.000000    2.560000        63.000000
# 50%    1485.500000    21.000000     4.000000    3.090000        74.000000
# 75%    1742.750000    23.000000     6.000000    3.545000        87.000000
# max    2000.000000    24.000000     8.000000    4.000000        99.000000
#
#        Midterm_Marks  Final_Marks  Study_Hours_Per_Day
# count    1030.000000  1030.000000          1030.000000
# mean       14.845631    24.875728             6.062136
# std         8.877224    14.492520             3.149348
# min         0.000000     0.000000             1.000000
# 25%         7.000000    12.000000             3.000000
# 50%        15.000000    25.000000             6.000000
# 75%        23.000000    38.000000             9.000000
# max        30.000000    50.000000            11.000000

# %%
df.drop_duplicates().sum()
# Out:
# Student_ID                                                       1500500
# Name                   Student_0Student_1Student_2Student_3Student_4S...
# Age                                                                20960
# Gender                 OtherFemaleOtherMaleMaleMaleFemaleMaleFemaleMa...
# Department             MathEEEEEECSMathMathPhysicsPhysicsPhysicsEEMat...
# Semester                                                            4438
# CGPA                                                             2891.86
# Attendance_Rate                                                  72411.0
# Scholarship                                                          205
# Admission_Date         2021-09-112020-01-262022-08-142021-02-242021-1...
# Midterm_Marks                                                      14832
# Final_Marks                                                        24877
# City                   MultanLahoreFaisalabadFaisalabadKarachiLahoreI...
# Study_Hours_Per_Day                                                 6053
# Fees_Paid              InstallmentFullFullInstallmentFullPendingPendi...
# dtype: object

# %%
df.isnull().sum()
# Out:
# Student_ID              0
# Name                    0
# Age                     0
# Gender                  0
# Department              0
# Semester                0
# CGPA                   51
# Attendance_Rate        31
# Scholarship             0
# Admission_Date          0
# Midterm_Marks           0
# Final_Marks             0
# City                    0
# Study_Hours_Per_Day     0
# Fees_Paid              22
# dtype: int64

# %%
df.dropna().sum()
# Out:
# Student_ID                                                       1386785
# Name                   Student_1Student_2Student_3Student_4Student_6S...
# Age                                                                19548
# Gender                 FemaleOtherMaleMaleFemaleMaleFemaleMaleMaleFem...
# Department             EEEEEECSMathPhysicsPhysicsPhysicsEEMathEECSPhy...
# Semester                                                            4150
# CGPA                                                             2834.38
# Attendance_Rate                                                  69659.0
# Scholarship                                                          189
# Admission_Date         2020-01-262022-08-142021-02-242021-10-242022-0...
# Midterm_Marks                                                      13728
# Final_Marks                                                        23148
# City                   LahoreFaisalabadFaisalabadKarachiIslamabadLaho...
# Study_Hours_Per_Day                                                 5721
# Fees_Paid              InstallmentFullFullInstallmentFullPendingPendi...
# dtype: object

# %%
df.isnull().sum()
# Out:
# Student_ID              0
# Name                    0
# Age                     0
# Gender                  0
# Department              0
# Semester                0
# CGPA                   51
# Attendance_Rate        31
# Scholarship             0
# Admission_Date          0
# Midterm_Marks           0
# Final_Marks             0
# City                    0
# Study_Hours_Per_Day     0
# Fees_Paid              22
# dtype: int64

# %%
pd.pivot_table(df, values='CGPA', index='Department', columns='Gender', aggfunc='mean',)
# Out:
# Gender        Female      Male     Other
# Department
# BBA         3.052000  3.034026  3.033279
# CS          2.991964  3.149206  3.068592
# EE          3.086415  3.035593  3.034340
# Math        3.004545  3.176250  2.986627
# Physics     2.991618  3.029865  3.055500

# %%
pd.pivot_table(df, values='Student_ID', index='Department', columns='Fees_Paid', aggfunc='count')
# Out:
# Fees_Paid   Full  Installment  Pending
# Department
# BBA           77           57       67
# CS            60           70       65
# EE            66           51       60
# Math          83           78       66
# Physics       80           49       79

# %%
pd.pivot_table(df,values=['Midterm_Marks', 'Final_Marks'], index='Department',aggfunc=['mean', 'max', 'min'])
# Out:
#                   mean                       max                       min  \
#            Final_Marks Midterm_Marks Final_Marks Midterm_Marks Final_Marks
# Department
# BBA          24.942029     14.724638          50            30           0
# CS           26.348485     14.580808          50            30           0
# EE           24.500000     14.595506          50            30           0
# Math         25.872340     14.982979          50            30           0
# Physics      22.646226     15.268868          50            30           0
#
#
#            Midterm_Marks
# Department
# BBA                    0
# CS                     0
# EE                     0
# Math                   0
# Physics                0

# %%
pd.pivot_table(df,values='Study_Hours_Per_Day',index=['City' , "Department"],columns="Semester" ,aggfunc='sum')
# Out:
# Semester                  1     2     3     4     5     6     7     8
# City       Department
# Faisalabad BBA         29.0  44.0  35.0  23.0  14.0  20.0  34.0  50.0
#            CS          22.0  22.0  29.0  65.0  19.0  38.0  26.0  22.0
#            EE          50.0  10.0   5.0  84.0  56.0  23.0  30.0  22.0
#            Math        18.0  31.0  28.0  70.0  18.0  11.0   2.0  30.0
#            Physics     16.0  47.0  34.0  34.0   9.0  27.0  19.0   NaN
# Islamabad  BBA         25.0  25.0  43.0  26.0  45.0  30.0  24.0  34.0
#            CS          20.0  26.0  19.0  40.0  21.0  11.0  29.0   1.0
#            EE          35.0   NaN  37.0  35.0  29.0  19.0  25.0  32.0
#            Math        55.0  45.0  43.0  10.0   9.0  60.0  64.0  21.0
#            Physics      6.0  42.0  27.0  31.0  27.0  40.0  39.0  18.0
# Karachi    BBA         21.0  17.0  36.0  12.0  44.0  50.0  53.0  36.0
#            CS          22.0  49.0  18.0  13.0  44.0  43.0  16.0  51.0
#            EE          37.0   2.0   5.0  25.0  49.0   6.0  45.0  68.0
#            Math        47.0  17.0  41.0  29.0  40.0  29.0   8.0  64.0
#            Physics     38.0   4.0  76.0  27.0  28.0  33.0  14.0  14.0
# Lahore     BBA         29.0  30.0  40.0  35.0  61.0  19.0  28.0  45.0
#            CS          34.0  25.0  17.0  12.0  38.0  36.0  33.0  25.0
#            EE          25.0  11.0  25.0  37.0  34.0  47.0  40.0  40.0
#            Math        42.0  25.0  36.0  45.0  34.0  24.0  37.0  29.0
#            Physics     34.0  58.0  43.0  45.0  66.0  50.0  49.0  24.0
# Multan     BBA         50.0   5.0  62.0  34.0  33.0  39.0  23.0   3.0
#            CS          43.0  29.0  14.0  21.0  47.0  32.0  33.0  34.0
#            EE           1.0  13.0  43.0  13.0  12.0  11.0  19.0  23.0
#            Math        18.0  32.0  50.0  53.0  49.0  62.0  32.0  37.0
#            Physics     45.0  50.0  33.0  12.0  24.0  43.0  23.0  32.0

# %%
pd.pivot_table(df, values="Scholarship" , index="City" , columns="Department" , aggfunc="sum")
# Out:
# Department  BBA  CS  EE  Math  Physics
# City
# Faisalabad    5   8   9    11        5
# Islamabad     7   5   8     9        3
# Karachi       8  10  13    11       10
# Lahore       13   8   4     9       11
# Multan       13  16   2     5        7

# %%
sns.lineplot()

# %%
# plt.figure(figsize=(8,6))
sns.lineplot(data=df, x="Department", y="CGPA",hue='City')
# Out:
# <Axes: xlabel='Department', ylabel='CGPA'>

# %%
sns.boxplot(data=df, x="Semester", y="CGPA")
# Out:
# <Axes: xlabel='Semester', ylabel='CGPA'>

# %%
sns.scatterplot(data=df, x="Gender", y="Attendance_Rate")
# Out:
# <Axes: xlabel='Gender', ylabel='Attendance_Rate'>

# %%
sns.pairplot(df[["CGPA" , "Final_Marks" , "Study_Hours_Per_Day"]])

# %%
sns.heatmap(df.corr(numeric_only=True) , annot=True)
# Out:
# <Axes: >
